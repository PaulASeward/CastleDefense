# %%
from visualizeFieldUtils import *
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = create_football_field()
plt.show()

# %% [markdown]
# ## Show Tracking Data at Events

# %%
gameId, playId, week = 2022090800, 56, 1


plot_single_play_events(playId, gameId, week)

# %% [markdown]
# ## Show Movement from Player Tracking Data

# %%
gameId, playId, week = 2022090800, 56, 1

plot_single_play_tracked_movements(playId, gameId, week)
